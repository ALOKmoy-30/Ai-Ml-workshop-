# %%
# leq1

# %% [markdown]
# #build a calculator
# #concepts - casting,variables,datatypes

# %%
a = int(input("enter no. 1:"))
b = int(input("enter no. 2:"))
print (f"addition is : {a+b}")
print (f"subtraction is : {a-b}")
print (f"multiplication is : {a*b}")
print (f"division is : {a/b}")
# Out:
# enter no. 1:10
# enter no. 2:20
# addition is : 30
# subtraction is : -10
# multiplication is : 200
# division is : 0.5

# %%
#student info
name = input("enter students name:")
age = int(input("enter students age :"))
depar = input ("enter department:")
print (f"students details are {name},{age},{depar}")
# Out:
# enter students name:alok
# enter students age :19
# enter department:ece
# students details are alok,19,ece

# %%
# EXERCISE
a = float(input("number 1:"))
b = float(input("number 2:"))
print (f"sum :{a+b}")
# Out:
# number 1:10.5
# number 2:2.5
# sum :13.0

# %%
# list vs tupple
roles = ["ai","freelance","designer","tester"] #list
ags = (18,13,20,21,22) # tupple
# set vs dictionary
names={"alex":"data scientist"} #dictionary key value pairs
payscale = {19020,20000} #set

# %%
# if-else statements ,indentation
age =int(input("enter your age:"))
if age>=18:
  print("you are eligable for driving")
else:
  print("you are not eligable for driving")
# Out:
# enter your age:19
# you are eligable for driving

# %%
# if else elif
#find the biggest out of three
a= int(input("input the 1stno:"))
b= int(input("input the 2ndtno:"))
c= int(input("input the 3rdno:"))
if a>b and a>c :
  print(f"{a} is greatest")
elif b>a and b>c :
  print(f"{b} is greatest ")
else:
  print(f"{c} is greatest")
# Out:
# input the 1stno:1
# input the 2ndtno:2
# input the 3rdno:5
# 5 is greatest

# %%
# module
import math
a = int (input("number:"))
print (f"{(math.sqrt(a))} is the square root of the number")
# Out:
# number:25
# 5.0 is the square root of the number
